# %% [markdown]
# # Basic Model Steps

# %% [markdown]
# ## Import the libraries

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np
from sklearn.preprocessing import StandardScaler , LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## Load Data

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Standardization 
se = StandardScaler()
df['Encode_total_bill'] =  se.fit_transform(df[['total_bill']])
df['Encode_tip'] = se.fit_transform(df[['tip']])

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  Encode_total_bill  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2          -0.314711
# 1         10.34  1.66    Male     No   Sun  Dinner     3          -1.063235
# 2         21.01  3.50    Male     No   Sun  Dinner     3           0.137780
# 3         23.68  3.31    Male     No   Sun  Dinner     2           0.438315
# 4         24.59  3.61  Female     No   Sun  Dinner     4           0.540745
# ..          ...   ...     ...    ...   ...     ...   ...                ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3           1.040511
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2           0.832275
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2           0.324630
# 242       17.82  1.75    Male     No   Sat  Dinner     2          -0.221287
# 243       18.78  3.00  Female     No  Thur  Dinner     2          -0.113229
#
#      Encode_tip
# 0     -1.439947
# 1     -0.969205
# ...

# %%
# seperat the feature  X and y the traget/labels y 
'''X = df[['Encode_total_bill']]
y = df['Encode_tip'] '''
X = df[['total_bill']]
y = df['tip']

# %%
#split the data into train and test
X_train, X_test , y_train , y_test = train_test_split(X,y,train_size=0.8)

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict([[15]])
# Out:
# /home/mebi/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.50652442])

# %%
#predication 
y_pred = model.predict (X_test )

# %%
from sklearn.metrics import mean_squared_error, r2_score
print('MSE: ', mean_squared_error(y_test, y_pred))
print('R2: ', r2_score(y_test, y_pred))
# Out:
# MSE:  1.2013289964238243
# R2:  0.38810408992021517

# %%
import pickle
pickle.dump(model, open('./save_models/model_01.pk1', 'wb'))

# %%
# load the model
import pickle
model_load = pickle.load(open('./save_models/model_01.pk1', 'rb') )

# %%
model_load.predict([[15]])
# Out:
# /home/mebi/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.50652442])

# %%
#just checking out for own how the 80 and 20 percentage split

# %%
X_test.value_counts().sum()
# Out:
# 49

# %%
X_train.value_counts().sum()
# Out:
# 195

# %%
195+49
# Out:
# 244

# %%
va = df['total_bill'].value_counts().sum()

# %%
va * 0.8
# Out:
# 195.20000000000002

# %%
va * 0.2
# Out:
# 48.800000000000004

# %%
df[df.total_bill == 15 ]['tip'].mean()
# Out:
# 2.99827868852459
