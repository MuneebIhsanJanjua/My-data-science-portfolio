# %%
# !git clone https://github.com/AammarTufail/six-months_python_for_data_science-mentorship-program/blob/cae4f9dd78012fd99409f5dd0b195dcb207f287b/07_machine_learning/14_decision_tree.ipynb
# Out:
# Cloning into '14_decision_tree.ipynb'...
# fatal: repository 'https://github.com/AammarTufail/six-months_python_for_data_science-mentorship-program/blob/cae4f9dd78012fd99409f5dd0b195dcb207f287b/07_machine_learning/14_decision_tree.ipynb/' not found
